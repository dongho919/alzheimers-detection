# %%
#imports
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import pathlib

# %%
class_names = ['NonDemented', 'Demented']
num_classes = len(class_names)
batch_size = 64
input_shape = (208, 176, 3)
AUTOTUNE = tf.data.experimental.AUTOTUNE

def one_hot_label(image, label):
    label = tf.one_hot(label, num_classes)
    return image, label

# %%
train_dir = pathlib.Path('../Project/Alzheimer_s Dataset_binary/train')
test_dir = pathlib.Path('../Project/Alzheimer_s Dataset_binary/test')

train_dataset = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        labels='inferred',
        class_names=class_names,
        batch_size=batch_size,
        image_size=input_shape[0:2])

test_dataset = tf.keras.utils.image_dataset_from_directory(
        test_dir,
        labels='inferred',
        class_names=class_names,
        batch_size=batch_size,
        image_size=input_shape[0:2])

for images, labels, in train_dataset.take(1):
    plt.imshow(images[0].numpy().astype('uint8'))
    plt.title(class_names[labels[0]])
    
train_dataset = train_dataset.map(one_hot_label, num_parallel_calls=AUTOTUNE)
test_dataset = test_dataset.map(one_hot_label, num_parallel_calls=AUTOTUNE)
# Out:
# Found 5121 files belonging to 2 classes.
# Found 1279 files belonging to 2 classes.

# %%
#Building the CNN
model = keras.Sequential(
    [
        #Defines the input sizes
        keras.Input(input_shape),
        #Creates the convolutional layer
        layers.Conv2D(16, kernel_size=(3,3), activation='relu'),
        layers.Conv2D(16, kernel_size=(3,3), activation='relu'),
        layers.MaxPool2D(),
        
        layers.SeparableConv2D(32, kernel_size=(3,3), activation='relu'),
        layers.SeparableConv2D(32, kernel_size=(3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPool2D(),
        
        layers.SeparableConv2D(64, kernel_size=(3,3), activation='relu'),
        layers.SeparableConv2D(64, kernel_size=(3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPool2D(),
        
        layers.SeparableConv2D(128, kernel_size=(3,3), activation='relu'),
        layers.SeparableConv2D(128, kernel_size=(3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPool2D(),
        
        layers.Dropout(0.2),
        
        layers.SeparableConv2D(256, kernel_size=(3,3), activation='relu'),
        layers.SeparableConv2D(256, kernel_size=(3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPool2D(),
        
        layers.Dropout(0.2),
        
        layers.Flatten(),
        
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.7),
        
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        
        layers.Dense(64, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        
        layers.Dense(num_classes, activation='softmax'),
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/3963718897.py in <module>
#       1 #Building the CNN
# ----> 2 model = keras.Sequential(
#       3     [
#       4         #Defines the input sizes
#       5         keras.Input(input_shape),
#
# NameError: name 'keras' is not defined

# %%
epochs = 30
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
 
history = model.fit(train_dataset, epochs=epochs,validation_data=test_dataset)
# Out:
# Epoch 1/30
# 81/81 [==============================] - 106s 1s/step - loss: 0.7989 - accuracy: 0.5813 - val_loss: 0.7041 - val_accuracy: 0.4996
# Epoch 2/30
# 81/81 [==============================] - 103s 1s/step - loss: 0.6667 - accuracy: 0.6645 - val_loss: 0.7094 - val_accuracy: 0.4996
# Epoch 3/30
# 81/81 [==============================] - 100s 1s/step - loss: 0.6223 - accuracy: 0.6751 - val_loss: 0.6942 - val_accuracy: 0.4996
# Epoch 4/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.5994 - accuracy: 0.6799 - val_loss: 0.7011 - val_accuracy: 0.5004
# Epoch 5/30
# 81/81 [==============================] - 104s 1s/step - loss: 0.5636 - accuracy: 0.7063 - val_loss: 0.7882 - val_accuracy: 0.5004
# Epoch 6/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.5382 - accuracy: 0.7323 - val_loss: 1.3672 - val_accuracy: 0.5004
# Epoch 7/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.5005 - accuracy: 0.7428 - val_loss: 1.8475 - val_accuracy: 0.5004
# Epoch 8/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.4454 - accuracy: 0.7879 - val_loss: 2.5859 - val_accuracy: 0.5004
# Epoch 9/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.4106 - accuracy: 0.8112 - val_loss: 1.6446 - val_accuracy: 0.5145
# Epoch 10/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.3284 - accuracy: 0.8592 - val_loss: 4.2828 - val_accuracy: 0.5285
# Epoch 11/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.2716 - accuracy: 0.8844 - val_loss: 0.8780 - val_accuracy: 0.6349
# Epoch 12/30
# 81/81 [==============================] - 101s 1s/step - loss: 0.2671 - accuracy: 0.8908 - val_loss: 0.8645 - val_accuracy: 0.6380
# Epoch 13/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.1991 - accuracy: 0.9217 - val_loss: 3.6055 - val_accuracy: 0.5051
# Epoch 14/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.1761 - accuracy: 0.9313 - val_loss: 2.1201 - val_accuracy: 0.5332
# Epoch 15/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.1504 - accuracy: 0.9412 - val_loss: 1.3685 - val_accuracy: 0.6114
# Epoch 16/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.1422 - accuracy: 0.9436 - val_loss: 1.6863 - val_accuracy: 0.5895
# Epoch 17/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0961 - accuracy: 0.9656 - val_loss: 2.8079 - val_accuracy: 0.5254
# Epoch 18/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.1315 - accuracy: 0.9498 - val_loss: 1.1150 - val_accuracy: 0.6568
# Epoch 19/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0921 - accuracy: 0.9656 - val_loss: 1.3475 - val_accuracy: 0.6396
# Epoch 20/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0952 - accuracy: 0.9662 - val_loss: 1.6386 - val_accuracy: 0.6208
# Epoch 21/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0909 - accuracy: 0.9664 - val_loss: 1.1868 - val_accuracy: 0.6865
# Epoch 22/30
# 81/81 [==============================] - 103s 1s/step - loss: 0.0716 - accuracy: 0.9756 - val_loss: 1.0279 - val_accuracy: 0.6888
# Epoch 23/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0703 - accuracy: 0.9760 - val_loss: 1.1469 - val_accuracy: 0.6411
# Epoch 24/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0762 - accuracy: 0.9731 - val_loss: 1.0025 - val_accuracy: 0.7240
# Epoch 25/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0872 - accuracy: 0.9654 - val_loss: 1.1268 - val_accuracy: 0.6826
# Epoch 26/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0537 - accuracy: 0.9813 - val_loss: 2.9551 - val_accuracy: 0.5301
# Epoch 27/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0585 - accuracy: 0.9789 - val_loss: 1.9523 - val_accuracy: 0.6130
# Epoch 28/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0858 - accuracy: 0.9701 - val_loss: 1.0739 - val_accuracy: 0.7232
# Epoch 29/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0564 - accuracy: 0.9811 - val_loss: 1.4953 - val_accuracy: 0.6646
# Epoch 30/30
# 81/81 [==============================] - 102s 1s/step - loss: 0.0688 - accuracy: 0.9758 - val_loss: 1.0932 - val_accuracy: 0.6826

# %%
score = model.evaluate(test_dataset,verbose=0)
print("Test loss:",score[0])
print("Test accuracy", score[1])
# Out:
# Test loss: 0.8245311975479126
# Test accuracy 0.7419859170913696

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.title('Naive CNN accuracy')

plt.plot(history.history['accuracy'], label = "training acc.")
plt.plot(history.history['val_accuracy'], label = "validation acc.")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training acc.', 'validation acc.'], loc='upper left')

plt.savefig("../Project/Result/CNN_PRE_MODEL_ACCURACY")
plt.show()
